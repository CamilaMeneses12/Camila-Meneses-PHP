# %%
pip install import
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement import (from versions: none)
# ERROR: No matching distribution found for import

# %% [markdown]
# # Mi primer codigo

# %%
valor1 = float(input("Registre un valor:"))
valor2 = float(input("Registre un segundo valor:"))
suma = valor1 + valor2
print("El resultado es de", suma)
# Out:
# Registre un valor: 12
# Registre un segundo valor: 2
# El resultado es de 14.0

# %%
def hola_mundo ():
    print ("HOLAA BIENVENIDO")
hola_mundo()
# Out:
# HOLAA BIENVENIDO

# %%
hola_mundo()
# Out:
# HOLAA BIENVENIDO

# %% [markdown]
# ### Identificador

# %%
variable = 1
print(variable)
# Out:
# 1

# %%
otra_variable = 'Otra'
print(otra_variable)
# Out:
# Otra

# %%
_mas_variables= [1,3,4]
print(_mas_variables)
# Out:
# [1, 3, 4]

# %%
Variable_4= True
print(Variable_4)
# Out:
# True

# %% [markdown]
# ### Comentarios

# %%
#Esto es un comentario de linea

# %%
"""Esto es un 
comentario de bloque,y el
de arriba un comentario de
linea 
"""
# Out:
# '\nEsto es un \ncomentario de bloque,y el\nde arriba un comentario de\nlinea \n'

# %% [markdown]
# ### Sangría

# %%
variable = 1
if (variable == 1):
    print("Aquí pongo el codigo a ejecutar.")
    print("Tiene una sangria de 4 espacios")
# Out:
# Aquí pongo el codigo a ejecutar.
# Tiene una sangria de 4 espacios

# %% [markdown]
# ### Variable

# %%
#Ejemplo de variable
n = 23
saludo = 'Hola que tal'

# %%
type(n) #Devuelve int
# Out:
# int

# %%
type(saludo) #Devuelve str
# Out:
# str

# %% [markdown]
# ### Constantes

# %%
IVA = 0.21

# %%
type(IVA)
# Out:
# float

# %%
precio = 25

# %%
type(precio)
# Out:
# int

# %%
precio_final = precio + (precio*IVA)

# %%
print("El precio final es: ",precio_final)
# Out:
# El precio final es:  30.25

# %% [markdown]
# ### Importar

# %%
import Constantes

# %%
precio = 25

# %%
precio_final = precio + (precio * Constantes.IVA)

# %%
print ("El precio final es: ", precio_final)
# Out:
# El precio final es:  30.25

# %% [markdown]
# ### Tipos de datos y operadores

# %%
Enteros(int):26,ob1101 (base binaria), ox3f4a (base hexadecimal)

# %%
Flotantes (float): 3.14,15.,-67.763

# %%
Complejos (complex): 0.117j

# %% [markdown]
# ### Operadores aritmeticos

# %%
suma = 3.13 + 6 
print(suma)
# Out:
# 9.129999999999999

# %%
resta = 3.13 - 6
print(resta)
# Out:
# -2.87

# %%
multiplicacion = 3.13 * 10
print(multiplicacion)
# Out:
# 31.299999999999997

# %%
division = 3.13 / 10
print(division)
# Out:
# 0.313

# %%
modulo = 3 % 10
print(modulo)
# Out:
# 3

# %%
division_entera = 3 // 10
print(division_entera)
# Out:
# 0

# %%
exponente = 3 ** 2
print(exponente)
# Out:
# 9

# %% [markdown]
# ### Operadores de asignación

# %%
resultado = 8 #resultado vale 10

# %%
resultado = 10
resultado += 10
print(resultado)
# Out:
# 20

# %%
resultado = 10
resultado -= 10
print(resultado)
# Out:
# 0

# %%
resultado = 20
resultado *= 36
print(resultado)
# Out:
# 720

# %%
resultado = 156
resultado /= 2
print(resultado)
# Out:
# 78.0

# %%
resultado = 50
resultado //= 15
print(resultado)
# Out:
# 3

# %%
resultado = 14
resultado %= 10
print(resultado)
# Out:
# 4

# %%
resultado = 8
resultado **= 2
print(resultado)
# Out:
# 64
